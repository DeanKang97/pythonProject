# %%
import pandas as pd  # 판다스
from konlpy.tag import *
from hanspell import spell_checker

import numpy as np

from nltk import FreqDist
# 실행했을 때 에러 메시지로 punkt에러 나면 밑에 명령어 한번 실행
# nltk.download("punkt")
from collections import Counter

# %%
data = pd.read_csv('fake_review_세라마이드 인텐스 크림.csv')  # 대상 데이터 로딩

data = data.drop_duplicates(["블로그내용"], keep="last")

data["블로그내용"] = data["블로그내용"].str.lower()  # 영어는 소문자로 통합

# %%
hp = ''
for d in data['블로그내용']:  # 리뷰 하나의 str로 합
    hp += str(d)

# %%
spelled_sent = spell_checker.check(hp)
hp += spelled_sent.checked

# %%
okt = Okt()
print("----------using .morphs--------")

phr = okt.morphs(hp)  # Parse phrase to morphemes 형태소 단위 구문 분석 
print(phr)

noun = phr
#불용어 제거
stopwords = ['뭐', '으면', '을', '의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', '에', '와', '한', '하다','.']
# Out:
# ----------using .morphs--------
# ['안녕하세요', '우사', '다', '에요', '*.*', '\n', '벌써', '부터', '건조한', '바람', '이', '부는', '가을', '이', '왔어요', 'ㅠㅠ', '\n\n', '하루', '사이', '에', '어쩜', '이렇게', '피부', '가', '바짝바짝', '말라가', '는', '게', '느껴지는', '거', '죠', '?....', '\n', '제', '가', '나이', '들어', '더', '확실히', '느껴지는', '건', '사실', '이', '아니라고', '해주세여', '....', 'ㅠ', '_', 'ㅠ', '\n\n\n', '꽃', '으로', '화장품', '을', '만드는', '마몽드', '에서', '\n', '무궁화', '의', '엄청나게', '강인한', '생명력', '을', '보고', '만든', '\n', '마몽드', '무궁화', '보습', '장벽', '크림', '\n\n\n\n\n\n \n\n', '마몽드', '의', '꽃', '이', '연구', '되고', '길러지는', '마몽드', '가든', '\n', '마몽드', '가든', '에서', '무궁화', '를', '연구', '하는', '중', '에', '재미있는', '이야기', '를', '하나', '발견', '했다고', '해', '요', '\n', '무궁화', '는', '매일', '아침', '태양', '에', '맞서', '100일', '동안', '한', '나무', '에서', '5천', '송이', '의', '꽃', '을', '피워내는', '강인한', '생명력', '의', '꽃', '인데', '\n\n', '무궁화', '줄기', '인', '목', '근', '피로', '부터', '스스로', '피부', '의', '수분', '을', '지키는', '강력한', '보습', '인자', '성분', '을', '발견', '해서', '\n', '무궁화', '의', '강력한', '보습', '인자', '에', '아모레퍼시픽', '독자', '개발', '한', '세', '라마', '이드를', '더해', '\n', '무궁화', '세', '라마', '이드', 'plus', '가', '되어', '무궁화', '보습', '장벽', '크림', '으로', '탄생', '했다고', '해', '요', '!', '\n\n\n', '저', '도', '일주일', '넘게', '사용', '하고', '있는데', '\n', '찬', '바람', '불기', '시작', '하는', '요즘', '부터', '겨울', '까지', '딱', '좋은', '\n', '보습', '크림', '추천', '하고', '싶어요', '\n\n', '그럼', '지금', '부터', '소개', '시작', '할게요', ',', '뿅', '!', '\n\n\n\n\n\n\n\n', '마몽드', '무궁화', '라인', '은', '10월', '출시', '로', '\n', '저', '는', '무궁화', '보습', '장벽', '크림', '기획', '세트', '로', '만나', '보았어요', '!', '\n\n\n', '무궁화', '모', '이스', '처', '세', '라마', '이드', '인텐스', '크림', '&', '무궁화', '모', '이스', '처', '세', '라마', '이드', '라이트', '크림', '\n', '스킨', '핏', '마스크', '팩', '과', '모', '이스', '처', '세', '라마', '이드', '슬', '리핑', '필링', '마스크', '로', '구성', '되어', '있더라구요', '\n\n', '한정', '으로', '무궁화', '보습', '장벽', '크림', '과', '함께', '\n', '마몽드', '무궁화', '라인', '제품', '을', '다양하게', '만', '나볼', '수', '있어서', '굿', '!', '\n\n\n\n\n\n\n\n', '마몽드', '모', '이스', '처', '세', '라마', '이드', '인텐스', '크림', '\n', '50', 'ml', '/', '29,000원', '\n\n\n', '무궁화', '는', '강력한', '천', '연', '보습', '인자', '를', '갖고', '있어서', '강인한', '생명력', '을', '자랑', '한다고', '해', '요', '\n\n', '마몽드', '에서는', '바로', '무궁화', '의', '강력한', '보습', '인자', '와', '함께', '아모레퍼시픽', '20년', '연구개발', '한', '\n', '세', '라마', '이드', '성분', '을', '더해', '한층', '더', '강화', '된', '무궁화', '세', '라마', '이드', 'plus', '로', '\n', "'", '빈틈', '없는', '밀착', '보습', "'", '을', '할', '수', '있는', '무궁화', '보습', '장벽', '크림', '을', '출시', '했어요', '!', '\n\n\n\n\n\n\n\n\n', '무궁화', '세', '라마', '이드', 'plus', '성분', '으로', '빈틈', '없는', '보습', '장벽', '을', '세워', '\n', '피부', '스스로', '수분', '을', '지킬', '수', '있도록', '케어', '해준다고', '해', '요', '\n\n', '겨울', '피부', '관리', '에', '강추템', '으로', '소개', '하고', '싶은', '마몽드', '무궁화', '보습', '장벽', '크림', '*.*', '\n', '참', ',', '세', '라마', '이드', '1%', '만', '함유', '가', '되어도', '피부', '장벽', '이', '복구', '된다는', '점', '다', '들', '아시', '죠', '?!', '\n\n\n', '찬', '바람', '불기', '전', '에는', '살짝', '무거운', '느낌이었는데', ',', '\n', '바람', '이', '확실히', '건조해진', '후', '에는', '겨울', '까지', '쓰기', '딱', '좋겠다', '싶더라구요', '\n', '중지', '성', '피부', '는', '보다', '가벼운', '제', '형', '인', '라이트', '크림', '을', '선택', '해주세요', '!', '\n\n\n\n\n\n\n\n', '향', '도', '은은하게', '느껴지면서', '발림', '감', '까지', '부드러운', '마몽드', '무궁화', '보습', '장벽', '크림', '*.*', '\n', '정말', '부드럽고', '펴', '발림', '이', '남다른', '것', '같아요', '!', '\n\n\n', '정말', '촉촉하고', '피부', '를', '즉각', '적', '으로', '부드럽고', '촉촉하게', '케어', '해줘요', '\n\n\n\n\n\n\n\n', '저', '는', '요즘', '듬뿍듬뿍', '사용', '하고', '있을', '정도', '로', '흡수', '력', '이', '빨라', '좋더라구요', '!', '\n', '저', '는', '건성', '피부', '라', '그런지', '지금', '부터', '겨울', '까지', '사용', '하기에', '딱', '좋다고', '생각', '이', '드는데', '\n', '중지', '성', '피부', '는', '살짝', '무겁게', '느껴질', '수', '있으니', '그럴', '땐', '산뜻한', '타입', '의', '라이트', '크림', '을', '선택', '하세용', '!', '\n\n\n\n\n\n\n\n', '흡수', '도', '빨라', '낮', ',', '밤', '으로', '모두', '사용', '하는', '마몽드', '무궁화', '보습', '장벽', '크림', '\n', '끈', '적임', '없이', '쏙', '흡수', '되어', '메이크업', '하면', '꿀', '피부', '로', '만들어', '주더라구요', '...', '헤헷', '\n\n\n\n\n\n\n\n\n\n', '사용', '전', ',', '후의', '차이', '를', '피부', '수분', '도로', '비교', '해봤어요', '\n', '바르기', '전', '은', '피부', '의', '수', '분도', '가', '33%', '로', '굉장히', '건조한', '상태', '인데', '\n', '마몽드', '무궁화', ' ...

# %%
arr = []
#불용어 제거
for i in range(0,len(noun)):
    if not noun[i] in stopwords:
        arr.append(noun[i])

# %%
#수동으로 단어 사전들을 만들어서 갯수를 세야함
#화장품이라면 "수부지", "지성" 등 합치고 "건성" "촉촉" 등 합침

vocab = FreqDist(np.hstack(arr))
goodWd = vocab['배송']+vocab['빨리']+vocab['빠름']
badWd = vocab['느려']+vocab['느리고']+vocab['느림']+vocab['늦게']
print('[배송]의 수 '+str(vocab['배송']))
print('[빨리]의 수 '+str(vocab['빨리']))
print('[빠름]의 수 '+str(vocab['빠름']))
print('[빠르게]의 수 '+str(vocab['빠르게']))
print('[느려]의 수 '+str(vocab['느려']))
print('[느리고]의 수 '+str(vocab['느리고']))
print('[늦게]의 수 '+str(vocab['늦게']))
print('[개통]의 수 '+str(vocab['개통']))
print("keyword:")
 #어느쪽이 더 우세한지 출력
if goodWd > badWd:
    print("배송 빠름")
else:
    print("배송 느림")
    

print(str(vocab['https']))
# Out:
# [배송]의 수 2
# [빨리]의 수 4
# [빠름]의 수 0
# [빠르게]의 수 12
# [느려]의 수 0
# [느리고]의 수 1
# [늦게]의 수 1
# [개통]의 수 0
# keyword:
# 배송 빠름
# 0

# %%
get_noun = okt.nouns(hp) #블로그 내용 중 명사만 추출
count_noun = Counter(get_noun)

noun_list = count_noun.most_common(100) #가장 많이 나타나는 명사 순으로 100개 저장
for v in noun_list:
    print(v)
# Out:
# ('보습', 874)
# ('크림', 868)
# ('피부', 851)
# ('무궁화', 688)
# ('장벽', 533)
# ('마몽드', 519)
# ('제품', 337)
# ('라마', 278)
# ('이드', 276)
# ('사용', 273)
# ('수', 205)
# ('인텐스', 171)
# ('것', 160)
# ('더', 156)
# ('성분', 153)
# ('이스', 150)
# ('느낌', 150)
# ('처', 146)
# ('꽃', 138)
# ('수분', 130)
# ('저', 114)
# ('겨울', 112)
# ('마스크', 106)
# ('라이트', 101)
# ('추천', 100)
# ('아리따움', 98)
# ('때', 96)
# ('각질', 93)
# ('해', 86)
# ('밀착', 85)
# ('이', 81)
# ('분', 79)
# ('막', 77)
# ('후', 76)
# ('바로', 74)
# ('케어', 72)
# ('제', 71)
# ('소개', 71)
# ('요', 71)
# ('아모레퍼시픽', 69)
# ('정말', 69)
# ('흡수', 69)
# ('정도', 67)
# ('발라', 63)
# ('감', 62)
# ('타입', 62)
# ('건성', 60)
# ('강화', 59)
# ('가격', 59)
# ('이벤트', 58)
# ('전', 57)
# ('거', 56)
# ('가든', 56)
# ('이번', 56)
# ('출시', 55)
# ('관리', 54)
# ('형', 53)
# ('결', 53)
# ('슬', 52)
# ('리핑', 52)
# ('빈틈', 52)
# ('스킨', 51)
# ('원고료', 51)
# ('아침', 50)
# ('인자', 50)
# ('요즘', 50)
# ('라인', 48)
# ('생각', 48)
# ('메이크업', 48)
# ('필링', 47)
# ('더욱', 47)
# ('가을', 46)
# ('화장', 46)
# ('용량', 45)
# ('팩', 44)
# ('끈', 44)
# ('날', 43)
# ('포스팅', 43)
# ('참여', 43)
# ('에너지', 42)
# ('매일', 41)
# ('지금', 41)
# ('좀', 41)
# ('때문', 41)
# ('위', 41)
# ('중', 40)
# ('하나', 40)
# ('가장', 40)
# ('피', 40)
# ('유지', 38)
# ('얼굴', 38)
# ('동안', 37)
# ('안', 37)
# ('목', 36)
# ('시간', 36)
# ('뷰티', 36)
# ('용감', 36)
# ('미세먼지', 36)
# ('바람', 35)
# ('생명력', 35)

# %%
link_count = 0 
contents = []

# \n 지우기 + 링크 개수 카운트
for i in arr:
    if not "\n" in i:  # \n 지우기
        contents.append(i)
    if "www." in i: #링크 개수 카운트
        link_count = link_count+1
print("링크 카운트: " + str(link_count)+"\n")

print(contents)
# Out:
# 링크 카운트: 29
#
# ['안녕하세요', '우사', '다', '에요', '*.*', '벌써', '부터', '건조한', '바람', '부는', '가을', '왔어요', 'ㅠㅠ', '하루', '사이', '어쩜', '이렇게', '피부', '바짝바짝', '말라가', '게', '느껴지는', '거', '죠', '?....', '제', '나이', '들어', '더', '확실히', '느껴지는', '건', '사실', '아니라고', '해주세여', '....', 'ㅠ', '_', 'ㅠ', '꽃', '화장품', '만드는', '마몽드', '에서', '무궁화', '엄청나게', '강인한', '생명력', '보고', '만든', '마몽드', '무궁화', '보습', '장벽', '크림', '마몽드', '꽃', '연구', '되고', '길러지는', '마몽드', '가든', '마몽드', '가든', '에서', '무궁화', '연구', '하는', '중', '재미있는', '이야기', '하나', '발견', '했다고', '해', '요', '무궁화', '매일', '아침', '태양', '맞서', '100일', '동안', '나무', '에서', '5천', '송이', '꽃', '피워내는', '강인한', '생명력', '꽃', '인데', '무궁화', '줄기', '인', '목', '근', '피로', '부터', '스스로', '피부', '수분', '지키는', '강력한', '보습', '인자', '성분', '발견', '해서', '무궁화', '강력한', '보습', '인자', '아모레퍼시픽', '독자', '개발', '세', '라마', '이드를', '더해', '무궁화', '세', '라마', '이드', 'plus', '되어', '무궁화', '보습', '장벽', '크림', '탄생', '했다고', '해', '요', '!', '저', '일주일', '넘게', '사용', '하고', '있는데', '찬', '바람', '불기', '시작', '하는', '요즘', '부터', '겨울', '까지', '딱', '좋은', '보습', '크림', '추천', '하고', '싶어요', '그럼', '지금', '부터', '소개', '시작', '할게요', ',', '뿅', '!', '마몽드', '무궁화', '라인', '10월', '출시', '로', '저', '무궁화', '보습', '장벽', '크림', '기획', '세트', '로', '만나', '보았어요', '!', '무궁화', '모', '이스', '처', '세', '라마', '이드', '인텐스', '크림', '&', '무궁화', '모', '이스', '처', '세', '라마', '이드', '라이트', '크림', '스킨', '핏', '마스크', '팩', '모', '이스', '처', '세', '라마', '이드', '슬', '리핑', '필링', '마스크', '로', '구성', '되어', '있더라구요', '한정', '무궁화', '보습', '장벽', '크림', '함께', '마몽드', '무궁화', '라인', '제품', '다양하게', '만', '나볼', '수', '있어서', '굿', '!', '마몽드', '모', '이스', '처', '세', '라마', '이드', '인텐스', '크림', '50', 'ml', '/', '29,000원', '무궁화', '강력한', '천', '연', '보습', '인자', '갖고', '있어서', '강인한', '생명력', '자랑', '한다고', '해', '요', '마몽드', '에서는', '바로', '무궁화', '강력한', '보습', '인자', '함께', '아모레퍼시픽', '20년', '연구개발', '세', '라마', '이드', '성분', '더해', '한층', '더', '강화', '된', '